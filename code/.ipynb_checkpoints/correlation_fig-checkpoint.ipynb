# %%
import pandas as pd

task_list = ['task1', 'task2', 'task3','task4']
subject = 'F'

df_data = pd.DataFrame()
for task in task_list:
    df = pd.read_csv("../time_series/" + subject + "/" + task + ".csv")
    df = df.iloc[len(df)-len(df)//10*10::10]
    df_data = pd.concat([df_data, df])

df_data
# Out:
#      Unnamed: 0    t     pNN50      RMSSD      CVRR       SDNN         HR  \
# 0             3   33  0.333333  55.406061  0.076326  63.707834  67.270471
# 10           13   43  0.400000  59.860453  0.085889  71.572846  73.133756
# 20           23   53  0.300000  50.326773  0.088032  68.833921  66.237237
# 30           33   63  0.266667  48.153058  0.089565  81.209470  69.232194
# 40           43   73  0.200000  46.056539  0.086721  76.969313  68.329516
# ..          ...  ...       ...        ...       ...        ...        ...
# 108         110  140  0.133333  36.545364  0.049397  44.326599  63.554647
# 118         120  150  0.133333  31.795871  0.033680  28.463707  68.026360
# 128         130  160  0.100000  28.829284  0.029742  23.984550  64.219505
# 138         140  170  0.066667  27.710200  0.036858  23.050447  65.088195
# 148         150  180  0.100000  36.048665  0.045548  36.891662  64.990690
#
#              LPS       CSI       SCL       EDA   correct     error  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cor = df_data.drop(['Unnamed: 0', 't', 'error', 'PE', 'NPE', 'PEm', 'NPEm', 'DMS'], axis=1).corr()
plt.figure(figsize=(20, 20))
sns.heatmap(cor, cmap= sns.color_palette('coolwarm', 10), annot=True,fmt='.2f', vmin = -1, vmax = 1)

# %%
sns.pairplot(df_data.drop(['Unnamed: 0', 't', 'error', 'PE', 'NPE', 'PEm', 'NPEm', 'DMS'], axis=1))

# %% [markdown]
# ## 順序尺度での検討

# %% [markdown]
# ### RMSSD

# %%
df_RMSSD = df_data.drop(['Unnamed: 0', 't', 'pNN50', 'CVRR', 'SDNN', 'HR', 'LPS', 'CSI', 'class', 'error', 'PE', 'NPE', 'PEm', 'NPEm', 'DMS'], axis=1)
df_RMSSD = df_RMSSD.sort_values('RMSSD').reset_index(drop=True)
df_RMSSD['order'] = df_RMSSD.index
df_RMSSD
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-d4adffa1731d> in <module>
# ----> 1 df_RMSSD = df_data.drop(['Unnamed: 0', 't', 'pNN50', 'CVRR', 'SDNN', 'HR', 'LPS', 'CSI', 'class', 'error', 'PE', 'NPE', 'PEm', 'NPEm', 'DMS'], axis=1)
#       2 df_RMSSD = df_RMSSD.sort_values('RMSSD').reset_index(drop=True)
#       3 df_RMSSD['order'] = df_RMSSD.index
#       4 df_RMSSD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
cor = df_RMSSD.corr()
plt.figure()
sns.heatmap(cor, cmap= sns.color_palette('coolwarm', 10), annot=True,fmt='.2f', vmin = -1, vmax = 1)

# %%
sns.pairplot(df_RMSSD)

# %% [markdown]
# ### pNN50

# %%
df_pNN50 = df_data.drop(['Unnamed: 0', 't', 'RMSSD', 'CVRR', 'SDNN', 'HR', 'LPS', 'CSI', 'class', 'error', 'PE', 'NPE', 'PEm', 'NPEm', 'DMS'], axis=1)
df_pNN50 = df_pNN50.sort_values('pNN50').reset_index(drop=True)
df_pNN50['order'] = df_pNN50.index
df_pNN50

# %%
cor = df_pNN50.corr()
plt.figure()
sns.heatmap(cor, cmap= sns.color_palette('coolwarm', 10), annot=True,fmt='.2f', vmin = -1, vmax = 1)

# %%
sns.pairplot(df_RMSSD)
