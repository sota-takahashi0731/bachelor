# %%
import pandas as pd
import numpy as np

score_name = 'VAS'

df = pd.read_excel('../subjective/total/' + score_name + '.xlsx')
df = df.drop(df.columns[0], axis=1)
df = df.drop(df.index[0])
df.columns = [0, 1, 2, 3]
df.loc['emotion'] = ['None', 'None', 'exist', 'exist']
df.loc['TP'] = ['Low', 'High', 'Low', 'High']
df
# Out:
#             0     1      2      3
# 1          57    47     80     59
# 2          35    68     70     97
# 3          40    66     83     80
# 4          60    75     94     94
# 5          45    65     58     81
# 6          55    65     89     98
# 7          70    93     99    100
# emotion  None  None  exist  exist
# TP        Low  High    Low   High

# %%
df_long = pd.DataFrame()
for i in df.columns:
    df_temp = pd.DataFrame()
    emo = df[i].loc['emotion']
    df_temp['emotion'] = [emo, emo, emo, emo, emo, emo]
    tp = df[i].loc['TP']
    df_temp['TP'] = [tp, tp, tp, tp, tp, tp]
    df_temp['score'] = [float(df[i].values[j]) for j in range(0,5)]
    df_long = pd.concat([df_long, df_temp])
df_long
# Out:
#   emotion    TP  score
# 0    None   Low   57.0
# 1    None   Low   35.0
# 2    None   Low   40.0
# 3    None   Low   60.0
# 4    None   Low   45.0
# 0    None  High   47.0
# 1    None  High   68.0
# 2    None  High   66.0
# 3    None  High   75.0
# 4    None  High   65.0
# 0   exist   Low   80.0
# 1   exist   Low   70.0
# 2   exist   Low   83.0
# 3   exist   Low   94.0
# 4   exist   Low   58.0
# 0   exist  High   59.0
# 1   exist  High   97.0
# 2   exist  High   80.0
# 3   exist  High   94.0
# 4   exist  High   81.0

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([df_long.loc[df_long['emotion']=='None']['score'].values[0:5].mean(),
          df_long.loc[df_long['emotion']=='None']['score'].values[5:10].mean()],
        marker = 'o', label='emotion_None')
ax.plot([df_long.loc[df_long['emotion']=='exist']['score'].values[0:5].mean(),
          df_long.loc[df_long['emotion']=='exist']['score'].values[5:10].mean()],
        marker = 'x', label = 'emotion_exist')
plt.xticks([0, 1], ['Low', 'High'])
ax.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,), borderaxespad=0)
circle = plt.Circle((1.02, 1.0,), 0.01, color='g', clip_on=False, transform=ax.transAxes)
ax.add_artist(circle)
plt.ylabel('mean score')
plt.xlabel('TP')
ax.set_title(score_name)
# Out:
# Text(0.5, 1.0, 'VAS')
