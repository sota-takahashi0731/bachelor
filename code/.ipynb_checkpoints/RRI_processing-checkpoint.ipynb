# %% [markdown]
# ○RRIデータの加工とunix時間の取得

# %%
import pandas as pd
import datetime as dt
import hrv

def RRI_data(df_rri, date):
    df_rri['time'] = date + df_rri['time']
    rri = df_rri.values[:, 1]
    t_datetime_rri = [dt.datetime.strptime(df_rri['time'][i], '%Y/%m/%d %H:%M:%S') for i in range(df_rri.shape[0])]
    t_unix_rri = [0] * df_rri.shape[0]
    t_unix_rri[0] = t_datetime_rri[0].timestamp()
    for i in range(1, df_rri.shape[0]):
        t_unix_rri[i] = t_unix_rri[i-1]+rri[i]*0.001
    return rri, t_unix_rri


subject_code = 'I'
file_num = '1'
task = 'reading1'
date = "2020/12/23 "
df_rri = pd.read_csv("../data/" + subject_code + "/" + file_num + "/mybeat.csv", header=5)
rri, t_unix_rri = RRI_data(df_rri, date)

# %%
time_tag = pd.read_csv('../data/' + subject_code + "/" + file_num + '/tags.csv', header=None)
print(time_tag, time_tag.values[0])
# Out:
#                0
# 0   1.608099e+09
# 1   1.608099e+09
# 2   1.608099e+09
# 3   1.608100e+09
# 4   1.608100e+09
# 5   1.608100e+09
# 6   1.608100e+09
# 7   1.608101e+09
# 8   1.608101e+09
# 9   1.608101e+09
# 10  1.608101e+09
# 11  1.608101e+09
# 12  1.608102e+09
# 13  1.608102e+09
# 14  1.608102e+09
# 15  1.608102e+09 [1.60809885e+09]

# %%
from E4 import time_sync
start_tag = time_tag.values[0]
end_tag = time_tag.values[1]
RRI, t_rri = time_sync(rri, t_unix_rri, start_tag, end_tag)
RRI, t = hrv.outlier_rm(RRI, t_rri)
# Out:
# 0 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-3980d9f732ac> in <module>
#       5     end_tag = time_tag[0].values[tag_index[1]]
#       6     RRI, t_rri = time_sync(rri, t_unix_rri, start_tag, end_tag)
# ----> 7     RRI, t = hrv.outlier_rm(RRI, t_rri)
#       8     df_RRI = pd.DataFrame()
#       9     df_RRI['t'] = t
#
# ~/Desktop/解析/code/hrv.py in outlier_rm(data, t)
#      35     t = np.array(t)
#      36
# ---> 37     dataf = sp.interpolate.interp1d(t,data,kind="cubic")
#      38     t = np.array(range(int(t.max())))
#      39
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/scipy/interpolate/interpolate.py in __init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     466         # Interpolation goes internally along the first axis
#     467         self.y = y
# --> 468         self._y = self._reshape_yi(self.y)
#     469         self.x = x
#     470         del y, x  # clean up namespace to prevent misuse; use attributes
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/scipy/interpolate/polyint.py in _reshape_yi(self, yi, check)
#     109                                            self._y_extra_shape[:-self._y_axis])
#     110             raise ValueError("Data must be of shape %s" % ok_shape)
# --> 111         return yi.reshape((yi.shape[0], -1))
#     112
#     113     def _set_yi(self, yi, xi=None, axis=None):
#
# ValueError: cannot reshape array of size 0 into shape (0,newaxis)

# %%
df_RRI = pd.DataFrame()
df_RRI['t'] = t
df_RRI['RRI'] = RRI
df_RRI.to_csv('../data/' + subject_code + '/RRI_' + task + '.csv', index=None)
