# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import r2_score

# %%
subject = 'H'
task_list = ['task1','task2','task3','task4']
params = ['pNN50', 'RMSSD', 'CVRR', 'SDNN', 'HR', 'LPS', 'CSI', 'SCL', 'HF', 'LF', 'LF/HF', 'TotalPow']

df = pd.DataFrame()
df_coefficient = pd.DataFrame()

r2 = []
error = []

for task in task_list:
    df2 = pd.read_csv("../time_series/" + subject + "/" + task + ".csv", index_col=0)
    model = linear_model.LinearRegression()    

    X = df2[params]
    y = df2['correct']
    
    model.fit(X,y)
    pred = model.predict(X)
    
    coefficient = model.coef_
    
    error.append(np.mean(y-model.predict(X)))
    r2.append(r2_score(pred, y))
    df_coefficient[task] = coefficient

                             


    
    df = pd.concat([df, df2])
df
# Out:
#        t  pNN50      RMSSD      CVRR       SDNN         HR          LPS  \
# 30    70  0.425  54.220741  0.122487  64.847674  64.405185  5274.596520
# 31    71  0.425  53.628053  0.121795  64.029075  68.168223  5204.426964
# 32    72  0.425  52.720159  0.121750  64.352860  71.326122  5065.292994
# 33    73  0.400  52.394925  0.123894  63.937487  70.616232  5048.875054
# 34    74  0.400  52.259208  0.126754  64.463343  65.020544  5207.512016
# ..   ...    ...        ...       ...        ...        ...          ...
# 168  208  0.225  42.395154  0.039884  37.710692  56.957964  2127.376831
# 169  209  0.225  41.692661  0.041127  38.518089  61.933461  2270.656348
# 170  210  0.225  43.001128  0.042626  38.596047  58.513245  2392.989689
# 171  211  0.225  42.588787  0.042117  38.581413  61.086844  2359.252622
# 172  212  0.225  42.664619  0.042484  38.128772  58.442785  2348.463039
#
#           CSI       CVI          HF  ...      TotalPow       SCL       EDA  \
# 30   4.167533  3.225039  328.365662  ...    392.146057  0.106102  0.109492
# 31   4.206226  3.219223  320.021670  ...    460.973272  0.106092  0.107985
# 32   4.255759  3.207455  250.269974  ...   5234.573922  0.106163  0.105631
# 33   4.247806  3.206045  253.819370  ...   3634.853469  0.106271  0.105073
# 34   4.249472  3.219480  312.752526  ...  13823.347243  0.106300  0.108985
# ..        ...       ...         ...  ...           ...       ...       ...
# 168  2.834559  2.830695  116.384510  ...    171.320914  3.683199  4.033725
# 169  2.879974  2.859002  110.401586  ...    131.922613  3.713187  3.929530
# 170  2.741962  2.881791  207.141098  ...    298.421718  3.742230  3.870128
# 171  2.778077  2.875625  265.884604  ...    342.818195  3.771983  4.123908
# 172  2.760646  2.873634  201.237571  ...    290.393621  3.803447  4.799628
#
#       correct     error        PE       NPE       PEm      NPEm       DMS
# 30   0.754646  0.245354  0.083286  0.754646  0.754646  0.754646  0.754646
# 31   0.784877  0.215123  0.083222  0.784877  0.784877  0.784877  0.784877
# 32   0.818431  0.181569  0.083288  0.818431  0.818431  0.818431  0.818431
# 33   0.838159  0.161841  0.083347  0.838159  0.838159  0.838159  0.838159
# 34   0.839253  0.160747  0.083343  0.839253  0.839253  0.839253  0.839253
# ..        ...       ...       ...       ...       ...       ...       ...
# 168  0.075311  0.924689  0.499022  0.075311  0.075311  0.075311  0.075311
# 169  0.100280  0.899720  0.502404  0.100280  0.100280  0.100280  0.100280
# 170  0.139495  0.860505  0.504160  0.139495  0.139495  0.139495  0.139495
# 171  0.184391  0.815609  0.493837  0.184391  0.184391  0.184391  0.184391
# 172  0.226333  0.773667  0.460831  0.226333  0.226333  0.226333  0.226333
#
# [703 rows x 22 columns]

# %%
model = linear_model.LinearRegression()

X = df[params]
y = df['correct']

model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
coefficient = model.coef_

df_coefficient['total'] = coefficient
df_coefficient.index = params

df_coefficient
# Out:
#               task1     task2      task3     task4     total
# pNN50     -0.011605 -0.999396   2.153864 -0.610814 -0.083829
# RMSSD     -0.001736  0.018007  -0.020793  0.028444  0.001202
# CVRR       1.100805 -8.132288 -15.208718 -2.835457  0.815486
# SDNN      -0.006618  0.002811   0.037971 -0.007573 -0.006569
# HR         0.000039 -0.007737  -0.007712 -0.004405 -0.001541
# LPS        0.000038 -0.000030  -0.000078 -0.000041  0.000020
# CSI        0.019093  0.026869  -0.160484  0.094904  0.054420
# SCL      -19.167992 -0.832415   0.007392 -0.540076 -0.068687
# HF         0.000009  0.000011   0.000003 -0.000032  0.000013
# LF        -0.000007 -0.000021   0.000002  0.000035 -0.000024
# LF/HF      0.003311  0.011858  -0.015821 -0.008160  0.010647
# TotalPow   0.000001 -0.000010   0.000004  0.000004 -0.000011

# %%
r2.append(model.score(X, y))
r2
# Out:
# [-0.9145251507982659,
#  -0.7059866110703095,
#  0.5003390871780821,
#  0.7655357364695436,
#  0.3376278742434371]

# %%
error.append(np.mean(y-model.predict(X)))
error
# Out:
# [-1.022306886634535e-15,
#  -4.733405949300068e-16,
#  -4.814742708833587e-18,
#  -1.0248212535001446e-16,
#  1.769566001554037e-16]

# %%
fig, ax = plt.subplots()
ax.scatter(y, model.predict(X))

# %%
# Out:
# -6.276320186717037e-17
