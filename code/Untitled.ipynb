# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import r2_score

# %%
subject = 'M'
task_list = ['task1','task2','task3','task4']
params = ['pNN50', 'RMSSD', 'CVRR', 'SDNN', 'HR', 'LPS', 'CSI', 'SCL']

df = pd.DataFrame()
df_coefficient = pd.DataFrame()

r2 = []
error = []

for task in task_list:
    df2 = pd.read_csv("../time_series/" + subject + "/" + task + ".csv", index_col=0)[::3]
    model = linear_model.LinearRegression()    

    X = df2[params]
    y = df2['correct']
    
    model.fit(X,y)
    pred = model.predict(X)
    
    coefficient = model.coef_
    
    error.append(np.mean(y-model.predict(X)))
    r2.append(r2_score(pred, y))
    df_coefficient[task] = coefficient

                             


    
    df = pd.concat([df, df2])
df
# Out:
#        t     pNN50      RMSSD      CVRR       SDNN         HR          LPS  \
# 32    62  0.233333  38.020668  0.100521  49.628098  77.640353  3436.367141
# 35    65  0.233333  38.051635  0.102562  49.992815  81.127604  3389.809527
# 38    68  0.266667  39.466291  0.100745  50.188735  77.709812  3478.502735
# 41    71  0.266667  39.372172  0.103211  49.400887  79.144359  3364.645090
# 44    74  0.233333  38.751133  0.101570  51.823913  90.694075  3348.052604
# 47    77  0.200000  37.762976  0.102158  52.856542  80.828559  3323.702798
# 50    80  0.133333  36.061652  0.095611  52.232902  87.400811  3149.825663
# 53    83  0.133333  36.189937  0.074323  47.782333  87.589106  2779.604634
# 56    86  0.066667  31.259898  0.066096  44.221537  82.006569  2002.680257
# 59    89  0.033333  29.464747  0.057745  39.648082  80.817371  1665.339986
# 62    92  0.033333  29.460592  0.050600  35.259626  82.151600  1444.989047
# ...

# %%
model = linear_model.LinearRegression()

X = df[params]
y = df['correct']

model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
coefficient = model.coef_

df_coefficient['total'] = coefficient
df_coefficient.index = params

df_coefficient
# Out:
#             task4       total
# pNN50   -2.561989   -2.561989
# RMSSD   -0.008870   -0.008870
# CVRR     3.395954    3.395954
# SDNN    -0.016703   -0.016703
# HR      -0.005257   -0.005257
# LPS      0.000268    0.000268
# CSI     -0.094808   -0.094808
# SCL   -113.590322 -113.590322

# %%
r2.append(model.score(X, y))
r2
# Out:
# [0.3873953486069369, 0.6201147932545963]

# %%
error.append(np.mean(y-model.predict(X)))
error
# Out:
# [3.962642180200559e-15, 3.962642180200559e-15]

# %%
fig, ax = plt.subplots()
ax.scatter(y, y-model.predict(X))

# %%
# Out:
# -6.276320186717037e-17
