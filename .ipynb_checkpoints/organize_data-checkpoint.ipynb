# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## データの連結

# %%
subjects_list = ['E', 'F', 'G', 'H']

df_params = pd.DataFrame()
for subject in subjects_list:
    df_param = pd.read_csv('data/' + subject + '/normalized_params.csv')
    df_param['tasknum'] = [1, 2, 3, 4]
    df_param['subject'] = subject
    df_params = pd.concat([df_params, df_param])
df_params = df_params.reindex(columns=['subject', 'tasknum', 'LPS', 'CSI', 'HR', 'SDNN', 'pNN50', 'RMSSD', 'HF', 'LF', 'LF/HF'])
df_params

# %%
df_logs = pd.DataFrame()
for subject in subjects_list:
    df_log = pd.read_csv('log/' + subject + '/total.csv')
    index_list = df_log.iloc[:, 0]
    df_log = df_log.drop(df_log.columns[0], axis=1)
    df_log.index = index_list
    df_log = df_log.T
    df_log['subject'] = subject
    df_log['tasknum'] = [1, 2, 3, 4]
    df_log.index = [0, 1, 2, 3]
    df_logs = pd.concat([df_logs, df_log])
df_params = pd.merge(df_params, df_logs, on=['subject', 'tasknum'], how='left')
df_params
# Out:
#    subject  tasknum       LPS       CSI        HR      SDNN     pNN50  \
# 0        E        1 -1.136657 -0.678226  1.651396  0.043615  0.829683
# 1        E        2  0.611263  2.625970  0.474201  0.305266  0.745162
# 2        E        3  0.708607  2.188343 -2.252735  0.479754  1.126213
# 3        E        4  0.462587  0.702669 -1.788480  0.391167  0.324260
# 4        F        1  0.196453  0.779613  0.299806  0.184939  0.273040
# 5        F        2 -0.028718  0.137567  0.450061  0.226454 -0.297343
# 6        F        3  0.974621  0.584319  0.042739  0.721369  0.936422
# 7        F        4 -0.679753  0.829530  0.495435 -0.337407 -0.634434
# 8        G        1  0.218174  0.947787  0.403792  0.239147  0.315619
# 9        G        2  0.565120  1.383945  0.090029  0.559816 -0.058334
# 10       G        3  0.089400  0.038074  0.246379 -0.220179  0.515013
# 11       G        4  0.217221  0.467828  0.392698  0.037676  0.258669
# 12       H        1  0.448858  1.114914 -0.152064  0.530934  0.231030
# 13       H        2 -0.009451  1.522376 -0.256698  0.181408 -0.274884
# 14       H        3  0.381940 -0.156875 -0.002038  0.121596  0.439883
# 15       H        4  0.474069  0.803495  0.661183  0.610813  0.713284
#
#        RMSSD        HF        LF  ...   correct     error    CA        PE  \
# 0  -0.983835 -5.307399  0.358589  ...  0.708333  0.291667  11.0  0.010417
# 1   0.770641  0.618655  0.676772  ...  0.647059  0.352941   6.0  0.117647
# 2   0.972756  1.279701  1.151607  ...  0.729167  0.270833  10.0  0.041667
# 3   0.424543 -0.422283  0.816333  ...  0.609375  0.390625   5.0  0.109375
# 4   0.083046 -0.565856  0.001883  ...  0.802083  0.197917  12.0  0.010417
# 5  -0.658444 -1.125921 -0.150238  ...  0.768116  0.231884   7.0  0.072464
# 6   0.785724  1.012615  0.842125  ...  0.736842  0.263158  10.0  0.073684
# 7  -0.559456 -0.257355 -0.603290  ...  0.784615  0.215385   7.0  0.046154
# 8   0.304869  0.714703 -0.951875  ...  0.583333  0.416667   8.0  0.166667
# 9   0.108415  0.613841  0.705137  ...  0.675676  0.324324   7.0  0.121622
# 10  0.439907  0.509138 -1.193952  ...  0.562500  0.437500   8.0  0.166667
# 11  0.338998  0.795997  0.497180  ...  0.500000  0.500000   5.0  0.243243
# 12  0.305838  0.361136  1.096365  ...  0.750000  0.250000  12.0  0.031250
# 13 -0.238867 -0.109539  0.130802  ...  0.662162  0.337838   5.0  0.162162
# 14  0.524291  0.285903  0.871194  ...  0.520833  0.479167   7.0  0.239583
# 15  0.627011  0.504985  1.451237  ...  0.662791  0.337209   8.0  0.162791
#
#          NPE       PEm      NPEm       DMS    TO           RT
# 0   0.281250  0.166667  0.125000  0.010417   0.0  1121.465783
# 1   0.235294  0.264706  0.088235  0.029412  28.0   895.111004
# 2   0.229167  0.145833  0.125000  0.020833   0.0   969.331329
# 3   0.281250  0.203125  0.187500  0.031250  32.0   786.736776
# 4   0.187500  0.125000  0.072917  0.010417   0.0  1522.691066
# 5   0.159420  0.159420  0.072464  0.043478  27.0  1121.706479
# 6   0.189474  0.178947  0.084211  0.021053   1.0  1767.980659
# 7   0.169231  0.138462  0.076923  0.015385  31.0   979.037715
# 8   0.250000  0.208333  0.208333  0.020833   0.0  1368.444823
# 9   0.202703  0.243243  0.081081  0.013514  22.0   916.676177
# 10  0.270833  0.229167  0.208333  0.020833   0.0  1314.571032
# 11  0.256757  0.283784  0.216216  0.013514  22.0   790.599564
# 12  0.218750  0.177083  0.072917  0.000000   0.0  1777.506217
# 13  0.175676  0.202703  0.135135  0.040541  22.0  1465.661300
# 14  0.239583  0.343750  0.135417  0.020833   0.0  1764.643428
# 15  0.174419  0.162791  0.174419  0.023256  10.0  1215.889400
#
# [16 rows x 21 columns]

# %%
df_vas = pd.read_excel('subjective/total/VAS.xlsx')
df_vas.index = df_vas.iloc[:, 0]
df_vas = df_vas.drop(df_vas.columns[0], axis=1)
vas_list = []
for subject in subjects_list:
    vas = df_vas.loc[subject].values
    for v in vas:
        vas_list.append(v)
df_params['VAS'] = vas_list
df_params
# Out:
#    subject  tasknum       LPS       CSI        HR      SDNN     pNN50  \
# 0        E        1 -1.136657 -0.678226  1.651396  0.043615  0.829683
# 1        E        2  0.611263  2.625970  0.474201  0.305266  0.745162
# 2        E        3  0.708607  2.188343 -2.252735  0.479754  1.126213
# 3        E        4  0.462587  0.702669 -1.788480  0.391167  0.324260
# 4        F        1  0.196453  0.779613  0.299806  0.184939  0.273040
# 5        F        2 -0.028718  0.137567  0.450061  0.226454 -0.297343
# 6        F        3  0.974621  0.584319  0.042739  0.721369  0.936422
# 7        F        4 -0.679753  0.829530  0.495435 -0.337407 -0.634434
# 8        G        1  0.218174  0.947787  0.403792  0.239147  0.315619
# 9        G        2  0.565120  1.383945  0.090029  0.559816 -0.058334
# 10       G        3  0.089400  0.038074  0.246379 -0.220179  0.515013
# 11       G        4  0.217221  0.467828  0.392698  0.037676  0.258669
# 12       H        1  0.448858  1.114914 -0.152064  0.530934  0.231030
# 13       H        2 -0.009451  1.522376 -0.256698  0.181408 -0.274884
# 14       H        3  0.381940 -0.156875 -0.002038  0.121596  0.439883
# 15       H        4  0.474069  0.803495  0.661183  0.610813  0.713284
#
#        RMSSD        HF        LF  ...     error    CA        PE       NPE  \
# 0  -0.983835 -5.307399  0.358589  ...  0.291667  11.0  0.010417  0.281250
# 1   0.770641  0.618655  0.676772  ...  0.352941   6.0  0.117647  0.235294
# 2   0.972756  1.279701  1.151607  ...  0.270833  10.0  0.041667  0.229167
# 3   0.424543 -0.422283  0.816333  ...  0.390625   5.0  0.109375  0.281250
# 4   0.083046 -0.565856  0.001883  ...  0.197917  12.0  0.010417  0.187500
# 5  -0.658444 -1.125921 -0.150238  ...  0.231884   7.0  0.072464  0.159420
# 6   0.785724  1.012615  0.842125  ...  0.263158  10.0  0.073684  0.189474
# 7  -0.559456 -0.257355 -0.603290  ...  0.215385   7.0  0.046154  0.169231
# 8   0.304869  0.714703 -0.951875  ...  0.416667   8.0  0.166667  0.250000
# 9   0.108415  0.613841  0.705137  ...  0.324324   7.0  0.121622  0.202703
# 10  0.439907  0.509138 -1.193952  ...  0.437500   8.0  0.166667  0.270833
# 11  0.338998  0.795997  0.497180  ...  0.500000   5.0  0.243243  0.256757
# 12  0.305838  0.361136  1.096365  ...  0.250000  12.0  0.031250  0.218750
# 13 -0.238867 -0.109539  0.130802  ...  0.337838   5.0  0.162162  0.175676
# 14  0.524291  0.285903  0.871194  ...  0.479167   7.0  0.239583  0.239583
# 15  0.627011  0.504985  1.451237  ...  0.337209   8.0  0.162791  0.174419
#
#          PEm      NPEm       DMS    TO           RT  VAS
# 0   0.166667  0.125000  0.010417   0.0  1121.465783   40
# 1   0.264706  0.088235  0.029412  28.0   895.111004   66
# 2   0.145833  0.125000  0.020833   0.0   969.331329   83
# 3   0.203125  0.187500  0.031250  32.0   786.736776   80
# 4   0.125000  0.072917  0.010417   0.0  1522.691066   60
# 5   0.159420  0.072464  0.043478  27.0  1121.706479   75
# 6   0.178947  0.084211  0.021053   1.0  1767.980659   94
# 7   0.138462  0.076923  0.015385  31.0   979.037715   94
# 8   0.208333  0.208333  0.020833   0.0  1368.444823   45
# 9   0.243243  0.081081  0.013514  22.0   916.676177   65
# 10  0.229167  0.208333  0.020833   0.0  1314.571032   58
# 11  0.283784  0.216216  0.013514  22.0   790.599564   81
# 12  0.177083  0.072917  0.000000   0.0  1777.506217   55
# 13  0.202703  0.135135  0.040541  22.0  1465.661300   65
# 14  0.343750  0.135417  0.020833   0.0  1764.643428   89
# 15  0.162791  0.174419  0.023256  10.0  1215.889400   98
#
# [16 rows x 22 columns]

# %%
nasa_item = ['AC', 'effort', 'frustration', 'mental_demand', 'physical_demand', 'time_pressure', 'WWL']
for item in nasa_item:
    df_item = pd.read_excel('subjective/total/NASA-TLX/' + item + '.xlsx')
    df_item.index = df_item.iloc[:, 0]
    df_item = df_item.drop(df_item.columns[0], axis=1)
    score_list = []
    for subject in subjects_list:
        score = df_item.loc[subject].values
        for s in score:
            score_list.append(s)
    df_params[item] = score_list
df_params
# Out:
#    subject  tasknum       LPS       CSI        HR      SDNN     pNN50  \
# 0        E        1 -1.136657 -0.678226  1.651396  0.043615  0.829683
# 1        E        2  0.611263  2.625970  0.474201  0.305266  0.745162
# 2        E        3  0.708607  2.188343 -2.252735  0.479754  1.126213
# 3        E        4  0.462587  0.702669 -1.788480  0.391167  0.324260
# 4        F        1  0.196453  0.779613  0.299806  0.184939  0.273040
# 5        F        2 -0.028718  0.137567  0.450061  0.226454 -0.297343
# 6        F        3  0.974621  0.584319  0.042739  0.721369  0.936422
# 7        F        4 -0.679753  0.829530  0.495435 -0.337407 -0.634434
# 8        G        1  0.218174  0.947787  0.403792  0.239147  0.315619
# 9        G        2  0.565120  1.383945  0.090029  0.559816 -0.058334
# 10       G        3  0.089400  0.038074  0.246379 -0.220179  0.515013
# 11       G        4  0.217221  0.467828  0.392698  0.037676  0.258669
# 12       H        1  0.448858  1.114914 -0.152064  0.530934  0.231030
# 13       H        2 -0.009451  1.522376 -0.256698  0.181408 -0.274884
# 14       H        3  0.381940 -0.156875 -0.002038  0.121596  0.439883
# 15       H        4  0.474069  0.803495  0.661183  0.610813  0.713284
#
#        RMSSD        HF        LF  ...    TO           RT  VAS  AC  effort  \
# 0  -0.983835 -5.307399  0.358589  ...   0.0  1121.465783   40  60      60
# 1   0.770641  0.618655  0.676772  ...  28.0   895.111004   66  80      85
# 2   0.972756  1.279701  1.151607  ...   0.0   969.331329   83  35      70
# 3   0.424543 -0.422283  0.816333  ...  32.0   786.736776   80  90      90
# 4   0.083046 -0.565856  0.001883  ...   0.0  1522.691066   60  38      64
# 5  -0.658444 -1.125921 -0.150238  ...  27.0  1121.706479   75  84      61
# 6   0.785724  1.012615  0.842125  ...   1.0  1767.980659   94  81      70
# 7  -0.559456 -0.257355 -0.603290  ...  31.0   979.037715   94  85      89
# 8   0.304869  0.714703 -0.951875  ...   0.0  1368.444823   45  45      65
# 9   0.108415  0.613841  0.705137  ...  22.0   916.676177   65  85      80
# 10  0.439907  0.509138 -1.193952  ...   0.0  1314.571032   58  70      70
# 11  0.338998  0.795997  0.497180  ...  22.0   790.599564   81  90      95
# 12  0.305838  0.361136  1.096365  ...   0.0  1777.506217   55  54      65
# 13 -0.238867 -0.109539  0.130802  ...  22.0  1465.661300   65  64      66
# 14  0.524291  0.285903  0.871194  ...   0.0  1764.643428   89  74      60
# 15  0.627011  0.504985  1.451237  ...  10.0  1215.889400   98  72      70
#
#     frustration  mental_demand  physical_demand  time_pressure    WWL
# 0            35             60                0             10  45.24
# 1            70             80                0             90  77.62
# 2            80             65                0             10  55.24
# 3            85             90                0             90  85.00
# 4            62             70               14             30  59.81
# 5            65             88               81             99  82.19
# 6            86             74               72             25  72.90
# 7            89             91               85             97  90.24
# 8            40             80               35             60  54.76
# 9            85             75               65             95  85.24
# 10           80             60               60             40  65.24
# 11           85             70               80             95  89.05
# 12           57             81               40             74  68.33
# 13           56             77               46             97  75.19
# 14           91             87               93             27  82.19
# 15          100             84               93             72  81.85
#
# [16 rows x 29 columns]

# %%
df_params['correct']
# Out:
# 0     0.708333
# 1     0.647059
# 2     0.729167
# 3     0.609375
# 4     0.802083
# 5     0.768116
# 6     0.736842
# 7     0.784615
# 8     0.583333
# 9     0.675676
# 10    0.562500
# 11    0.500000
# 12    0.750000
# 13    0.662162
# 14    0.520833
# 15    0.662791
# Name: correct, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cor = df_params[['LPS', 'CSI', 'HR', 'SDNN', 'pNN50', 'RMSSD', 'HF', 'LF', 'LF/HF', 'CA', 'correct', 'error', 'PE', 'NPE', 'PEm', 'NPEm', 'DMS', 'TO', 'RT']].corr()
plt.figure(figsize=(20, 20))
sns.heatmap(cor, cmap= sns.color_palette('coolwarm', 10), annot=True,fmt='.2f', vmin = -1, vmax = 1)

# %%
cor = df_params[['AC', 'effort', 'frustration', 'mental_demand', 'physical_demand', 'time_pressure', 'WWL', 'VAS', 'CA', 'correct', 'error', 'PE', 'NPE', 'PEm', 'NPEm', 'DMS', 'TO', 'RT']].corr()
plt.figure(figsize=(20, 20))
sns.heatmap(cor, cmap= sns.color_palette('coolwarm', 10), annot=True,fmt='.2f', vmin = -1, vmax = 1)

# %%
cor = df_params[['AC', 'effort', 'frustration', 'mental_demand', 'physical_demand', 'time_pressure', 'LPS', 'CSI', 'HR', 'SDNN', 'pNN50', 'RMSSD', 'HF', 'LF', 'LF/HF']].corr()
plt.figure(figsize=(20, 20))
sns.heatmap(cor, cmap= sns.color_palette('coolwarm', 10), annot=True,fmt='.2f', vmin = -1, vmax = 1)
